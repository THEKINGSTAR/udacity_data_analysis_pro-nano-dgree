# %% [markdown]
# ***
#
# ***
#
# # <h1><center>WRANGLING</center></h1>
#
# ***
# ***
# # GATHERING THE DATA
# * KNOW WHAT DATA IS NEED TO BE COLLECTED IN WHTAT FORM , AND FROM WHERE TO COLLECT IT
#
# ***
# # Asserting
# * Reading the datasets
# * EXAMINIG THE DATA AND THE QULITY OR TIDNY ISSUES WITH IT
#
# ***
# # Cleaning
# * ### Phase one   : Data Cleaning
#
#         1- Dealing with duplicate
#
#         2- Removing Non-exexting Data
#
#
#
# * ###  Phase Two   : Data Analysis in Python
#
# * ###  Phase Three : Visulaization and sharts
# ***

# %% [markdown]
# # PART 1 :: GATHERING THE DATA
# ***

# %%
import os
import time

import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup
import tweepy
import twython
import webbrowser
import json


import re
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### API key and secret:
#
# oauth_consumer_key
#
# oauth_consumer_secret
#
# ### Think of these as the user name and password that represents your Twitter developer app when making API requests.
#
# ***
# ### Access token and secret:
#
# oauth_token
#
# oauth_token_secret
#
# An access token and access token secret are user-specific credentials used to authenticate OAuth 1.0a API requests. They specify the Twitter account the request is made on behalf of.
#
# You can generate your own access token and token secret if you would like your app to make requests on behalf of the same Twitter account associated with your developer account on the Twitter developer app's details page.
#
# If you'd like to generate access tokens for a different user, see "Making requests on behalf of users" below.

# %%
##############################################
# help from YouTube 
# https://www.youtube.com/watch?v=dvAurfBB6Jk
##############################################
callback_uri ="oob"

# %%
#####################################################
####    HELP FROM  ####
#https://docs.tweepy.org/en/latest/auth_tutorial.html
#https://www.youtube.com/watch?v=dvAurfBB6Jk
#####################################################
start = time.time()
###################

consumer_key     = ""
consumer_secret  = ""
########
auth = tweepy.OAuthHandler(consumer_key, consumer_secret , callback_uri)
########
access_token        = ""
access_token_secret = ""

####################
print("Finshed in : {}".format(time.time()-start))
# Out:
# Finshed in : 0.0

# %%
# TESTING HTAT TWITTER ACEPTED MY CREDIENTIOAL , RESPOND WITH ASKING FOR AUTHENTICATION !!!
start = time.time()
###################

auth.set_access_token(access_token, access_token_secret)
redirect_url = auth.get_authorization_url()
print(redirect_url)

####################
print("Finshed in : {}".format(time.time()-start))
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=cBVj0AAAAAABNpWGAAABeEp1KkA
# Finshed in : 0.7209982872009277

# %% [markdown]
# ## Checking if twitter is get tweets from my tweeter home page !!????

# %%
api = tweepy.API(auth)

# %%
start = time.time()
###################

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
    
####################
print("\Finshed in : {}".format(time.time()-start))
# Out:
# Coronavirus pandemic gives health care workers a chance to shine on social media https://t.co/2RbTNc4cnl
# Aqumon, a Hong Kong robo adviser backed by Alibaba, is looking to expand to China where day traders tend to focus o… https://t.co/jRhKMVGSTs
# Python Django Crash Course 2021 https://t.co/lOBsuV60eX #django #python via @codek_tv
# Xiaomi Mi 11: Come for the specs, stay for the design (story by @Indianidle) https://t.co/TMnUjxnjIX
# Best live TV streaming service for cord-cutters: YouTube TV, Sling TV, Hulu and more compared https://t.co/dRvbN4sNkG
# RT @News18Tech: .@oneplus CEO @PeteLau on #OnePlus9R, the company's plans for India, and 5G, in conversation with @vishalmathur85. Read our…
# The race to 5G is more a marathon than a sprint, and T-Mobile is currently winning. But Verizon is coming in hot to… https://t.co/JJYKGRUy42
# Excited for The Falcon and the Winter Soldier? Here are 15 movies on Disney+ to whet your appetite and ease you int… https://t.co/v011U4iysk
# ...

# %% [markdown]
# ****

# %% [markdown]
# ## CHECKING IF I CAN GET SOM TWEETS FROM CERTAIN TWEETER ID !!

# %%
##########################################################################################
# ANOTHER HELP FROM THE ALMIGHTY STACKOVERFLOW
#https://stackoverflow.com/questions/46179718/how-to-export-tweets-to-txt-or-json-by-tweepy
##########################################################################################

start = time.time()
###################

name = "dog_rates"
tweetCount = 20
result = []
for tweet in api.user_timeline(id=name,count = tweetCount ):
    result.append({'text': tweet.text,'author_name': tweet.user.screen_name})
with open('test_20_tweet.json', 'w+') as f:
    json.dump(result, f)
    
###################
print("Finshed in : {}".format(time.time()-start))
# Out:
# Finshed in : 1.7609717845916748

# %%
#CHECK IF THE FILE I JUST GET 20  TWEET IN IT IS EXIST
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '5 - Project Workspace Complete and Submit Project.ipynb',
#  '5 - Project Workspace Complete and Submit Project.rar',
#  'cover.png',
#  'df.csv',
#  'image-predictions-3.tsv',
#  'image-predictions.tsv',
#  'test_20_tweet.json',
#  'tweet.json',
#  'tweet_json.txt',
#  'tweet_test.py',
#  'twitter-api.py',
#  'twitter-api.rtf',
#  'twitter-archive-enhanced-2.csv',
#  'twitter-archive-enhanced.csv',
#  'wrangle.ipynb',
#  'wrangle_api_df.csv',
#  'wrangle_archive_df.csv',
#  'wrangle_image_predictions_df.csv']

# %% [markdown]
# #### Testing if I IT get THE twwets from the id "dog_rates" AND I CAN READ IT

# %%
start = time.time()
###################

df_tweet_test = pd.read_json("test_20_tweet.json")
print(df_tweet_test)

###################
print("Finshed in : {}".format(time.time()-start))
# Out:
#                                                  text author_name
# 0   RT @JarrodBriley: I love him so much @dog_rate...   dog_rates
# 1             @SWatercolour this is delightful hector   dog_rates
# 2   RT @BruceHalperin: WHERE IS THE WEATHERMAN I J...   dog_rates
# 3                   @Sike1216 https://t.co/AF9QHbI019   dog_rates
# 4   This is Carlito. He misread today’s forecast. ...   dog_rates
# 5   @johncwingfield @Milliethegolden omg happy bir...   dog_rates
# 6   @PsairaHarrell @msuvets @dogfather i am so sor...   dog_rates
# 7   @EmmDash @ajamesparker is there a club? and wh...   dog_rates
# 8   @sevenseasofshy @ajamesparker margaret we have...   dog_rates
# 9   @edwardnelson4tn @ajamesparker we’re going bor...   dog_rates
# 10  This is Maximilian. His stimulus hit this morn...   dog_rates
# 11            @l_wardle00 @IvePetThatDog @ARLIowa omg   dog_rates
# 12  @IvePetThatDog @ARLIowa DONE! HE CAN’T WAIT ht...   dog_rates
# ...

# %% [markdown]
# ##### NOW I CAN GET TWEETS !!!

# %%
consumer_key     = ""
consumer_secret  = ""

access_token        = ""
access_token_secret = ""

# %% [markdown]
# ## Code proprovided by Udacity

# %%
df_1 = pd.read_csv("twitter-archive-enhanced.csv")
#df_1.head(1)

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
"""
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

"""


auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = df_1.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
if not os.path.isfile('tweet_json.txt'):
    with open('tweet_json.txt', 'w') as outfile:
        # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
        for tweet_id in tweet_ids:
            count += 1
            print(str(count) + ": " + str(tweet_id))
            try:
                tweet = api.get_status(tweet_id, tweet_mode='extended')
                print("Success")
                json.dump(tweet.json, outfile)
                outfile.write('\n')
            except tweepy.TweepError as e:
                print("Fail")
                fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %% [markdown]
# #### !^~^! TEWEETER # TRY THE GET  OTHER FILES

# %%
urls=["https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
      ,"https://d17h27t6h515a5.cloudfront.net/topher/2017/August/59a4e958_twitter-archive-enhanced/twitter-archive-enhanced.csv"
     ]


#response

# %% [markdown]
# #### DOWNLOAD ALL THE FILE FROM THERE LOCATION , DUE TO  MY SLOWWWWWWWW HOME INTERNT CONNECTION !!!!

# %%
#file_name = url[:-len("image-predictions.tsv")] ##WILL WORK ONLY FOR THAT PARTICULAR FILE NAME.
start = time.time()
###################

file_name = [urls[0].split("/")[-1],urls[1].split("/")[-1]]
for name in file_name:
    if not os.path.isfile(name):
        for url in urls:
            response = requests.get(url)
            with open (os.path.join(url.split("/")[-1]),mode="wb") as file:file.write(response.content)
                
###################
print("Finshed in : {}".format(time.time()-start))
# Out:
# Finshed in : 0.0010006427764892578

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '5 - Project Workspace Complete and Submit Project - Jupyter Notebook.pdf',
#  '5 - Project Workspace Complete and Submit Project-v2.ipynb',
#  '5 - Project Workspace Complete and Submit Project.ipynb',
#  '5 - Project Workspace Complete and Submit Project.rar',
#  'act_report.ipynb',
#  'act_report.pdf',
#  'cover.png',
#  'Data Analysis Professional - Udacity.pdf',
#  'df.csv',
#  'image-predictions-3.tsv',
#  'image-predictions.tsv',
#  'images',
#  'test_20_tweet.json',
#  'tweet.json',
#  'tweet_json.txt',
#  'tweet_test.py',
#  'twitter-api.py',
#  'twitter-api.rtf',
#  'twitter-archive-enhanced-2.csv',
#  'twitter-archive-enhanced.csv',
#  'twitter_archive_master.csv',
#  'Udacity Reviews.pdf',
#  'wrangle.ipynb',
#  'wrangle_act.ipynb',
#  'wrangle_act.pdf',
#  'wrangle_api_df.csv',
#  'wrangle_archive_df.csv',
#  'wrangle_image_predictions_df.csv',
#  'wrangle_report.ipynb',
#  'wrangle_report.pdf']

# %% [markdown]
# ###### YEP ALL THE  files been downloaded . amazing !!

# %% [markdown]
# #### READING THE TWWETS JSON FILE AND FILTERING IT INTO MORE AGGREGATED DATA AS PART OF DATA GATHERING

# %%
##################################################################################################################
# help from ::
#https://nfpdiscussions.udacity.com/t/concering-reading-twitter-jason-txt-file/41138/5
##################################################################################################################

start = time.time()
###################

df_list = []

with open('tweet_json.txt', 'r') as file:
    for line in file:
        tweet = json.loads(line)
        tweet_id = tweet['id']
        retweet_count = tweet['retweet_count']
        fav_count = tweet['favorite_count']
        user_count = tweet['user']['followers_count']
        df_list.append({'tweet_id':tweet_id,
                       'retweet_count': retweet_count,
                       'favorite_count': fav_count,
                       'user_count': user_count})
        
api_df = pd.DataFrame(df_list)
print(api_df.head(3))

###################
print("\nFinshed in : {}".format(time.time()-start))
# Out:
#              tweet_id  retweet_count  favorite_count  user_count
# 0  892420643555336193           8853           39467     3200889
# 1  892177421306343426           6514           33819     3200889
# 2  891815181378084864           4328           25461     3200889
#
# Finshed in : 0.2579984664916992

# %%
# cheking existing of the new file
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '5 - Project Workspace Complete and Submit Project - Jupyter Notebook.pdf',
#  '5 - Project Workspace Complete and Submit Project-v2.ipynb',
#  '5 - Project Workspace Complete and Submit Project.ipynb',
#  '5 - Project Workspace Complete and Submit Project.rar',
#  'act_report.ipynb',
#  'act_report.pdf',
#  'cover.png',
#  'Data Analysis Professional - Udacity.pdf',
#  'df.csv',
#  'image-predictions-3.tsv',
#  'image-predictions.tsv',
#  'images',
#  'test_20_tweet.json',
#  'tweet.json',
#  'tweet_json.txt',
#  'tweet_test.py',
#  'twitter-api.py',
#  'twitter-api.rtf',
#  'twitter-archive-enhanced-2.csv',
#  'twitter-archive-enhanced.csv',
#  'twitter_archive_master.csv',
#  'Udacity Reviews.pdf',
#  'wrangle.ipynb',
#  'wrangle_act.ipynb',
#  'wrangle_act.pdf',
#  'wrangle_api_df.csv',
#  'wrangle_archive_df.csv',
#  'wrangle_image_predictions_df.csv',
#  'wrangle_report.ipynb',
#  'wrangle_report.pdf']

# %% [markdown]
# #### QUICK READING OF THE DATA FILES AND  CHECK FOR ITS PROPERTIES !!

# %%
start = time.time()
###################

archive_df           = pd.read_csv("twitter-archive-enhanced.csv")
image_predictions_df = pd.read_csv("image-predictions.tsv",sep="\t")
#api_df               = pd.read_json("tweet_json.txt",lines=True)

data_frams           = [archive_df , image_predictions_df , api_df]

## Geting General looking for the data in the taples and check of its Excesting

for d in data_frams:
    #d.head(1)
    print("\n"+"*"*20)
    print("Shape of the data:\n{}".format(d.shape))
    print("*"*20)
    print(d.info())
    print("*"*20)
    print(d.describe())
    print("*"*20)
    print("\nCount of actual data in each column against the total number of rows:\n\n{}".format(d.count()))
    print("*"*20)
    print("\nNon existing  data in each row:\n\n{} ".format(d.isnull().sum()))
    print("*"*20)
    print("Duplicated data :\n\n{}".format(d.nunique()))
    print("\n"+"*"*150)

###################
print("Finshed in : {}".format(time.time()-start))
# Out:
# ********************
# Shape of the data:
# (2356, 17)
# ********************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
# ...

# %% [markdown]
# ***
#
# ***
#
# # <h1><center>WRANGLING</center></h1>
#
# ***
# ***
# # PART 2 :: Asserting

# %% [markdown]
#  ## 1- Copying the datas into wrangling frames

# %%
start = time.time()
###################

# original date frams 
data_frams           = [archive_df , image_predictions_df , api_df]

wrangle_archive_df = archive_df.copy()
wrangle_archive_df.to_csv("wrangle_archive_df.csv")

wrangle_image_predictions_df = image_predictions_df.copy()
wrangle_image_predictions_df.to_csv("wrangle_image_predictions_df.csv")

wrangle_api_df = api_df.copy()
wrangle_api_df.to_csv("wrangle_api_df.csv")

###################
print("Finshed in : {}".format(time.time()-start))
# Out:
# Finshed in : 0.09209871292114258

# %%
#checking for the new wrangling data wich i gona work on it
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '5 - Project Workspace Complete and Submit Project - Jupyter Notebook.pdf',
#  '5 - Project Workspace Complete and Submit Project-v2.ipynb',
#  '5 - Project Workspace Complete and Submit Project.ipynb',
#  '5 - Project Workspace Complete and Submit Project.rar',
#  'act_report.ipynb',
#  'act_report.pdf',
#  'cover.png',
#  'Data Analysis Professional - Udacity.pdf',
#  'df.csv',
#  'image-predictions-3.tsv',
#  'image-predictions.tsv',
#  'images',
#  'test_20_tweet.json',
#  'tweet.json',
#  'tweet_json.txt',
#  'tweet_test.py',
#  'twitter-api.py',
#  'twitter-api.rtf',
#  'twitter-archive-enhanced-2.csv',
#  'twitter-archive-enhanced.csv',
#  'twitter_archive_master.csv',
#  'Udacity Reviews.pdf',
#  'wrangle.ipynb',
#  'wrangle_act.ipynb',
#  'wrangle_act.pdf',
#  'wrangle_api_df.csv',
#  'wrangle_archive_df.csv',
#  'wrangle_image_predictions_df.csv',
#  'wrangle_report.ipynb',
#  'wrangle_report.pdf']

# %% [markdown]
# ## 2- Visualy and Programmatic  Examinig the Data

# %% [markdown]
# ## A - Visualy Assessment
# 1 - Open the FILES \[ 'api_df.csv' , 'archive_df.csv' , 'image_predictions_df.csv' ]
#      In Exel APP ON  MY WINDOWS DESKTOP AND CHECK THE DATA

# %% [markdown]
# ## B - Programmatic Assessment

# %%
start = time.time()
###################

wrangle_archive_df           = pd.read_csv("wrangle_archive_df.csv")
wrangle_image_predictions_df = pd.read_csv("wrangle_image_predictions_df.csv")
wrangle_api_df               = pd.read_csv("wrangle_api_df.csv")

wrangle_data_frams           = [wrangle_archive_df , wrangle_image_predictions_df , wrangle_api_df]

for d in wrangle_data_frams:
    #print(d.head(1))
    print("\n"+"*"*20)
    print("Shape of the data:\n{}".format(d.shape))
    print("*"*20)
    print(d.info())
    print("*"*20)
    print(d.describe())
    print("*"*20)
    print("\nCount of actual data in each column against the total number of rows:\n\n{}".format(d.count()))
    print("*"*20)
    print("\nNon existing  data in each row:\n\n{} ".format(d.isnull().sum()))
    print("*"*20)
    print("Duplicated data :\n\n{}".format(d.nunique()))
    print("\n"+"*"*150)

###################
print("Finshed in : {}".format(time.time()-start))
# Out:
# ********************
# Shape of the data:
# (2356, 18)
# ********************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  2356 non-null   int64
#  1   tweet_id                    2356 non-null   int64
#  2   in_reply_to_status_id       78 non-null     float64
#  3   in_reply_to_user_id         78 non-null     float64
#  4   timestamp                   2356 non-null   object
#  5   source                      2356 non-null   object
#  6   text                        2356 non-null   object
#  7   retweeted_status_id         181 non-null    float64
#  8   retweeted_status_user_id    181 non-null    float64
#  9   retweeted_status_timestamp  181 non-null    object
#  10  expanded_urls               2297 non-null   object
# ...

# %%
wrangle_archive_df[wrangle_archive_df.rating_numerator<10].count()[0]
# Out:
# 440

# %%
vlaues = wrangle_archive_df[wrangle_archive_df.rating_denominator<10].count()
vlaues
# Out:
# Unnamed: 0                    3
# tweet_id                      3
# in_reply_to_status_id         1
# in_reply_to_user_id           1
# timestamp                     3
# source                        3
# text                          3
# retweeted_status_id           0
# retweeted_status_user_id      0
# retweeted_status_timestamp    0
# expanded_urls                 2
# rating_numerator              3
# rating_denominator            3
# name                          3
# doggo                         3
# floofer                       3
# pupper                        3
# puppo                         3
# dtype: int64

# %% [markdown]
# # 3- Asserting issues with Data

# %% [markdown]
# ## Quality
#
# 1-
#
# A - Missing vlues in "twitter-archive-enhanced" Data set in
# * "in_reply_to_status_id"
# * "in_reply_to_user_id"
# * "retweeted_status_id"
# * "retweeted_status_user_id"
# * 'name'
# * "source"
#
# columns .
#
# B -  Missing values in "twitter-archive-enhanced" in :
#
#     * Row # "2351"  with tweet id 	"666049248165822465"  , have name with "None" vlaue .
#     * Row # "2352"  with tweet id	"666044226329800704"  , have name with "a" letter vlaue .
#     * Row # "2353"  with tweet id	"666033412701032449"  , have name with "a" letter vlaue .
#     * Row # "2354"  with tweet id	"666029285002620928"  , have name with "a" letter vlaue .
#     * Row # "2355"  with tweet id    "666020888022790149" , have name with "None" vlaue .
#
#
#
#
#
# 2- Duplicated Tweets in "twitter-archive-enhanced" Data in
#
#     "retweeted_status_id"        ,with count of    181
#     "retweeted_status_user_id"   ,with count of    181
#     "retweeted_status_timestamp" ,with count of    181
#
# columns.
# ***
# 3- DATA TYPES
# * IN "twitter-archive-enhanced", THE "retweeted_status_timestamp" COLUMN  DATA TYPE IS 'object' NOT "TIME STAMP" OR "DATE TIME " TYPE.
# * IN "twitter-archive-enhanced" , "tweet_id" column is "int"  type with no need to do analysis on it so it may convert to string .
#
# 4- DATA VALUES
#   * Validity:
#               IN "twitter-archive-enhanced" there is :
#
#               * "rating_denominator" HAVE DATA VLUES LESS THAN 10 WICH IS THE MINMIMUM RATING FOR DOG , with count of 3 ratings
#
#               * "rating_numerator"   HAVE DATA VLUES LESS THAN 10 WICH IS THE MINMIMUM RATING FOR DOG , with count of 440 ratings
#
# 5 - More than one column in "image_predictions" ,  for the smae vlaue and messure in  AKA ( DOGS IS seperated IN 4 COLUMNS )
#
#      [ p1, p2 ,p3 ]
#
#      [ p1_dog , p2_dog , p3_dog ]
#
# 	 [ p1_conf , p2_conf , p3_conf ]
#
#
#
# 6 - In "image_predictions" , columns header are vales not variables name
#
# ***
# ## Tidiness
#
#
# 1 - All the data is in relation to each other but seperated into three taples
#
# 2 - COLUMN with no useful , or repated data , must combining or droped from the final data , combining the columns doggo, puppo, pupper, floofer into a single column

# %% [markdown]
# ***
#
# ***
#
# # <h1><center>WRANGLING</center></h1>
#
# ***
# ***
# # PART 3 :: CLEANING
# ***
# * ### Phase one   : Data Cleaning
#
#         1- Dealing with duplicate
#
#         2- Removing Non-exexting Data
#
#
#
# * ###  Phase Two   : Data Analysis in Python
#
# * ###  Phase Three : Visulaization and sharts
#
# ***

# %%
# REMEMBER THE DATA FRAMS I WILL WORK WITH

wrangle_data_frams           = [ wrangle_archive_df , wrangle_image_predictions_df , wrangle_api_df ]

# %% [markdown]
# ## Merging all the data frams in one data fram to work with as they share more simlarity and columns variable typs

# %%
merged_archive_image = wrangle_archive_df.merge(wrangle_image_predictions_df,how="left")

# %%
merge_archive_image_api = merged_archive_image.merge(wrangle_api_df,how="left")
merge_archive_image_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  2356 non-null   int64
#  1   tweet_id                    2356 non-null   int64
#  2   in_reply_to_status_id       78 non-null     float64
#  3   in_reply_to_user_id         78 non-null     float64
#  4   timestamp                   2356 non-null   object
#  5   source                      2356 non-null   object
#  6   text                        2356 non-null   object
#  7   retweeted_status_id         181 non-null    float64
#  8   retweeted_status_user_id    181 non-null    float64
#  9   retweeted_status_timestamp  181 non-null    object
#  10  expanded_urls               2297 non-null   object
#  11  rating_numerator            2356 non-null   int64
#  12  rating_denominator          2356 non-null   int64
# ...

# %% [markdown]
# # Creating data frame with the only columns , that i will work on

# %% [markdown]
# ### Define :

# %% [markdown]
# ### AS the image prediction  \[ #1 ] is the most trusted one there is no need for the other predictions

# %% [markdown]
# ### Code :

# %%
# cleaning_wrangle_archive_df = wrangle_archive_df[["tweet_id","timestamp","source","text"
#                                                    ,"name","rating_numerator","rating_denominator",]]
#                                                    +wrangle_image_predictions_df[["p1","p1_conf","p1_dog"]]
# cleaning_wrangle_archive_df
##########################################################################################################################
#wrangle_archive_df[["tweet_id","timestamp","source","text","name"
                    #,"rating_numerator","rating_denominator",]]
                    #+wrangle_image_predictions_df[["p1","p1_conf","p1_dog"]]
#merge_archive_image_api.drop().isnull()
#merge_archive_image_api.retweeted_status_user_id.drop().isnull()
#########################################################################################################################
cleaned_archive_image_api = merge_archive_image_api[["tweet_id","timestamp","source","text","name"
                                                     ,"rating_numerator","rating_denominator","p1"
                                                     ,"p1_conf","p1_dog","doggo","floofer","pupper","puppo"]]

# %% [markdown]
# ### Testing

# %%
cleaned_archive_image_api.head(2)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text     name  \
# 0  This is Phineas. He's a mystical boy. Only eve...  Phineas
# 1  This is Tilly. She's just checking pup on you....    Tilly
#
#    rating_numerator  rating_denominator   p1  p1_conf p1_dog doggo floofer  \
# 0                13                  10  NaN      NaN    NaN  None    None
# 1                13                  10  NaN      NaN    NaN  None    None
#
#   pupper puppo
# 0   None  None
# 1   None  None

# %% [markdown]
# ## Define :
# ### MULTIPLE DOG STAGES
# ### For dog stage, there are some rows with multiple dog stages:

# %% [markdown]
# ### Code :

# %%
# handle none
cleaned_archive_image_api.doggo.replace  ('None', '', inplace=True)
cleaned_archive_image_api.floofer.replace('None', '', inplace=True)
cleaned_archive_image_api.pupper.replace ('None', '', inplace=True)
cleaned_archive_image_api.puppo.replace  ('None', '', inplace=True)

# merge into column
cleaned_archive_image_api['dog_stage'] = cleaned_archive_image_api.doggo + cleaned_archive_image_api.floofer + cleaned_archive_image_api.pupper + cleaned_archive_image_api.puppo

# handle multiple stages
cleaned_archive_image_api.loc[ cleaned_archive_image_api.dog_stage == 'doggopupper', 'dog_stage'  ] = 'doggo, pupper'
cleaned_archive_image_api.loc[ cleaned_archive_image_api.dog_stage == 'doggopuppo', 'dog_stage'   ] = 'doggo, puppo'
cleaned_archive_image_api.loc[ cleaned_archive_image_api.dog_stage == 'doggofloofer', 'dog_stage' ] = 'doggo, floofer'

# handle missing values
cleaned_archive_image_api.loc[cleaned_archive_image_api.dog_stage == '', 'dog_stage'] = np.nan
# Out:
# C:\Users\KING\anaconda3\lib\site-packages\pandas\core\series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# <ipython-input-166-34cec4d950c6>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_archive_image_api['dog_stage'] = cleaned_archive_image_api.doggo + cleaned_archive_image_api.floofer + cleaned_archive_image_api.pupper + cleaned_archive_image_api.puppo
# C:\Users\KING\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## Testing :

# %%
#cleaned_archive_image_api.loc[ cleaned_archive_image_api.dog_stage =='']
#cleaned_archive_image_api.loc[ cleaned_archive_image_api.dog_stage =='None']
#cleaned_archive_image_api.loc[ cleaned_archive_image_api.dog_stage == 'doggopuppo']

mulit = ["doggopupper","doggopuppo",'doggofloofer']
for name in mulit :
    print('\n'+cleaned_archive_image_api.loc[ cleaned_archive_image_api.dog_stage == name])
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, name, rating_numerator, rating_denominator, p1, p1_conf, p1_dog, doggo, floofer, pupper, puppo, dog_stage]
# Index: []
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, name, rating_numerator, rating_denominator, p1, p1_conf, p1_dog, doggo, floofer, pupper, puppo, dog_stage]
# Index: []
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, name, rating_numerator, rating_denominator, p1, p1_conf, p1_dog, doggo, floofer, pupper, puppo, dog_stage]
# Index: []

# %% [markdown]
# ## Define :
# ### Creating "dog_type" column based on the tweet text from the tweet owner , and fill the column with "dog_type" from the text . or no text but dont leave it empty or with "Null", "non" , "NAN" .

# %% [markdown]
# Code :

# %%
####################################################################################################################################################
#help from 
#https://stackoverflow.com/questions/46921465/extract-substring-from-text-in-a-pandas-dataframe-as-new-column
#df['EXTRACT'] = df.TEXT.str.extract('({})'.format('|'.join(word_list)),flags=re.IGNORECASE, expand=False).str.lower().fillna('')
#df.loc[df['shield'] > 6]
####################################################################################################################################################

dog_types=["pupper","doggo","puppo","floofer"]

#cleaned_archive_image_api["dog_type"] =cleaned_archive_image_api["text"].str.extract("(doggo|floofer|pupper|puppo)")
#cleaned_archive_image_api["dog_type"] = cleaned_archive_image_api.text.str.find("map(lambda x:x, dog_types)")


cleaned_archive_image_api["dog_type"] = cleaned_archive_image_api.text.str.extract('({})'.format('|'.join(dog_types)),flags=re.IGNORECASE, expand=False).str.lower().fillna('')
# Out:
# <ipython-input-168-1f7474d9b24f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_archive_image_api["dog_type"] = cleaned_archive_image_api.text.str.extract('({})'.format('|'.join(dog_types)),flags=re.IGNORECASE, expand=False).str.lower().fillna('')

# %% [markdown]
# ## Testing :

# %%
cleaned_archive_image_api.isnull().sum()
# Out:
# tweet_id                 0
# timestamp                0
# source                   0
# text                     0
# name                     0
# rating_numerator         0
# rating_denominator       0
# p1                    2355
# p1_conf               2355
# p1_dog                2355
# doggo                    0
# floofer                  0
# pupper                   0
# puppo                    0
# dog_stage             1976
# dog_type                 0
# dtype: int64

# %%
cleaned_archive_image_api.sample(10)
# Out:
#                 tweet_id                  timestamp  \
# 1540  689659372465688576  2016-01-20 04:03:02 +0000
# 2303  666996132027977728  2015-11-18 15:07:24 +0000
# 718   783466772167098368  2016-10-05 00:40:09 +0000
# 2063  671159727754231808  2015-11-30 02:52:03 +0000
# 1910  674416750885273600  2015-12-09 02:34:18 +0000
# 1210  715680795826982913  2016-03-31 23:22:53 +0000
# 925   755110668769038337  2016-07-18 18:43:07 +0000
# 2305  666837028449972224  2015-11-18 04:35:11 +0000
# 2239  667937095915278337  2015-11-21 05:26:27 +0000
# 303   836397794269200385  2017-02-28 02:09:08 +0000
#
#                                                  source  \
# 1540  <a href="http://twitter.com/download/iphone" r...
# 2303  <a href="http://twitter.com/download/iphone" r...
# 718   <a href="http://twitter.com/download/iphone" r...
# 2063  <a href="http://twitter.com/download/iphone" r...
# 1910  <a href="http://twitter.com/download/iphone" r...
# ...

# %%
cleaned_archive_image_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   object
#  2   source              2356 non-null   object
#  3   text                2356 non-null   object
#  4   name                2356 non-null   object
#  5   rating_numerator    2356 non-null   int64
#  6   rating_denominator  2356 non-null   int64
#  7   p1                  1 non-null      object
#  8   p1_conf             1 non-null      float64
#  9   p1_dog              1 non-null      object
#  10  doggo               2356 non-null   object
#  11  floofer             2356 non-null   object
#  12  pupper              2356 non-null   object
#  13  puppo               2356 non-null   object
#  14  dog_stage           380 non-null    object
# ...

# %% [markdown]
# ### Define :
#
# "time stammp" column type is "object" AKA "STRING" WICH IS not suitaple for futer aggregate throw selecting time period ,
# must converted to "time date" type .

# %% [markdown]
# ## Code :

# %%
cleaned_archive_image_api.timestamp = pd.to_datetime(cleaned_archive_image_api.timestamp)
cleaned_archive_image_api.tweet_id  = cleaned_archive_image_api.tweet_id.astype(str)
# Out:
# C:\Users\KING\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# ## Testing :

# %%
cleaned_archive_image_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   object
#  1   timestamp           2356 non-null   datetime64[ns, UTC]
#  2   source              2356 non-null   object
#  3   text                2356 non-null   object
#  4   name                2356 non-null   object
#  5   rating_numerator    2356 non-null   int64
#  6   rating_denominator  2356 non-null   int64
#  7   p1                  1 non-null      object
#  8   p1_conf             1 non-null      float64
#  9   p1_dog              1 non-null      object
#  10  doggo               2356 non-null   object
#  11  floofer             2356 non-null   object
#  12  pupper              2356 non-null   object
#  13  puppo               2356 non-null   object
#  14  dog_stage           380 non-null    object
# ...

# %% [markdown]
# ## Define :
# ## DECIMAL DOG RATINGS
# ### For dog ratings, there are some observations with decimal ratings

# %% [markdown]
# ## Code

# %%
cleaned_archive_image_api[cleaned_archive_image_api.text.str.contains(r"(\d+\.\d*\/\d+)")][['text', 'rating_numerator']]
# Out:
# C:\Users\KING\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                                                    text  rating_numerator
# 45    This is Bella. She hopes her smile made you sm...                 5
# 340   RT @dog_rates: This is Logan, the Chow who liv...                75
# 695   This is Logan, the Chow who lived. He solemnly...                75
# 763   This is Sophie. She's a Jubilant Bush Pupper. ...                27
# 1689  I've been told there's a slight possibility he...                 5
# 1712  Here we have uncovered an entire battalion of ...                26

# %% [markdown]
# ## Testing :

# %%
re_decm = r"(\d+\.\d*\/\d+)"
cleaned_archive_image_api.loc[ cleaned_archive_image_api['rating_numerator'] == re_decm ]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, name, rating_numerator, rating_denominator, p1, p1_conf, p1_dog, doggo, floofer, pupper, puppo, dog_stage, dog_type]
# Index: []

# %%
cleaned_archive_image_api["rating_numerator"]
# Out:
# 0       13
# 1       13
# 2       12
# 3       13
# 4       12
#         ..
# 2351     5
# 2352     6
# 2353     9
# 2354     7
# 2355     8
# Name: rating_numerator, Length: 2356, dtype: int64

# %% [markdown]
# ## Defing :
# ### No need for the text column after extracted the wonted infomation from it , now to drop the text column from the data frame

# %% [markdown]
# ## Code :

# %%
cleaned_archive_image_api.drop(columns='text',inplace=True)
# Out:
# C:\Users\KING\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ## Testing :

# %%
cleaned_archive_image_api
# Out:
#                 tweet_id                 timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00
# 1     892177421306343426 2017-08-01 00:17:27+00:00
# 2     891815181378084864 2017-07-31 00:18:03+00:00
# 3     891689557279858688 2017-07-30 15:58:51+00:00
# 4     891327558926688256 2017-07-29 16:00:24+00:00
# ...                  ...                       ...
# 2351  666049248165822465 2015-11-16 00:24:50+00:00
# 2352  666044226329800704 2015-11-16 00:04:52+00:00
# 2353  666033412701032449 2015-11-15 23:21:54+00:00
# 2354  666029285002620928 2015-11-15 23:05:30+00:00
# 2355  666020888022790149 2015-11-15 22:32:08+00:00
#
#                                                  source      name  \
# 0     <a href="http://twitter.com/download/iphone" r...   Phineas
# 1     <a href="http://twitter.com/download/iphone" r...     Tilly
# 2     <a href="http://twitter.com/download/iphone" r...    Archie
# 3     <a href="http://twitter.com/download/iphone" r...     Darla
# ...

# %%
cleaned_archive_image_api.dog_type.value_counts()
# Out:
#            1933
# pupper      276
# doggo       100
# puppo        38
# floofer       9
# Name: dog_type, dtype: int64

# %%
cleaned_archive_image_api.tweet_id.drop_duplicates(inplace=True)
cleaned_archive_image_api
# Out:
# <ipython-input-218-675aab29bf3d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_archive_image_api.tweet_id.drop_duplicates(inplace=True)
#                 tweet_id                 timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00
# 1     892177421306343426 2017-08-01 00:17:27+00:00
# 2     891815181378084864 2017-07-31 00:18:03+00:00
# 3     891689557279858688 2017-07-30 15:58:51+00:00
# 4     891327558926688256 2017-07-29 16:00:24+00:00
# ...                  ...                       ...
# 2351  666049248165822465 2015-11-16 00:24:50+00:00
# 2352  666044226329800704 2015-11-16 00:04:52+00:00
# 2353  666033412701032449 2015-11-15 23:21:54+00:00
# 2354  666029285002620928 2015-11-15 23:05:30+00:00
# 2355  666020888022790149 2015-11-15 22:32:08+00:00
#
# ...

# %%
cleaned_archive_image_api.to_csv("twitter_archive_master.csv",index=False)

# %% [markdown]
# ### EXPORTING THE FINAL DATA TO THE "twitter_archive_master.csv" , FILE AND TEST SOME VISULIZATION ON IT

# %%
twitter_archive_master =pd.read_csv("twitter_archive_master.csv")

# %%
dog_types=["pupper","doggo","puppo","floofer"]

dog_types_count = twitter_archive_master.dog_type.value_counts()
dog_types_count
# Out:
# pupper     276
# doggo      100
# puppo       38
# floofer      9
# Name: dog_type, dtype: int64

# %%
plt.pie(dog_types_count,labels=dog_types);
plt.title("Dog type tweets percentage")
# Out:
# Text(0.5, 1.0, 'Dog type tweets percentage')

# %% [markdown]
# #### Trying to make it more clearly

# %%
plot = dog_types_count.plot.pie(title="Dog type tweets percentage",labels=dog_types ,autopct='%1.1f%%',subplots=True, shadow=True,explode=(0.1 , 0.2 , 0.3 , 0.3)
                                , figsize=(11, 6));
#plot.title("Dog type tweets percentage")

# %%
dog_names = twitter_archive_master.name.unique()
len(dog_names)
# Out:
# 957

# %%
dog_names_count = twitter_archive_master.name.value_counts()
dog_names_count
# Out:
# None       745
# a           55
# Charlie     12
# Oliver      11
# Lucy        11
#           ...
# Sweet        1
# Kevon        1
# Billl        1
# Rhino        1
# Bode         1
# Name: name, Length: 957, dtype: int64

# %%
plt.pie(dog_names_count,labels=dog_names);

# %% [markdown]
# #### Selecting the most apperd name to make it more clearly

# %%
highst_count = twitter_archive_master.name.value_counts().loc[lambda x: x>5]
highst_count.plot.pie(title="Most tweeted names for dogs  percentage"
                      ,autopct='%1.1f%%'
                      ,subplots=True
                      ,shadow=True
                      
                      , figsize=(11, 6)
                      );

# %% [markdown]
# ##### THIS IS OUT OF CONTROL Trying to make it more clearly , BY GETING HELP FROM THE EXPERTS !!

# %%
##################################################################################################################
#help from
#https://stackoverflow.com/questions/22320356/pandas-get-values-from-column-that-appear-more-than-x-times
##################################################################################################################

highst_count = twitter_archive_master.name.value_counts().loc[lambda x: x>5][2:]
size         = highst_count.size

highst_count
# Out:
# Charlie    12
# Oliver     11
# Lucy       11
# Cooper     11
# Tucker     10
# Penny      10
# Lola       10
# Bo          9
# Winston     9
# Sadie       8
# the         8
# Daisy       7
# Toby        7
# Buddy       7
# Bailey      7
# an          7
# Scout       6
# Dave        6
# Leo         6
# Oscar       6
# Stanley     6
# Milo        6
# Jax         6
# Rusty       6
# Jack        6
# Koda        6
# Bella       6
# Name: name, dtype: int64

# %%
highst_count = twitter_archive_master.name.value_counts().loc[lambda x: x>5][2:]
size = highst_count.size
highst_count.plot.pie(title="Most names , tweeted for dogs, percentage"
                      ,autopct='%1.1f%%'
                      ,subplots=True
                      ,shadow=True
                      ,radius = 1 #,explode=size
                      , figsize=(11, 6)
                      );

# %%
highst_count = twitter_archive_master.dog_stage.value_counts().loc[lambda x: x>5][2:]
size         = highst_count.size

highst_count
# Out:
# puppo            29
# doggo, pupper    12
# floofer           9
# Name: dog_stage, dtype: int64

# %%
highst_count = twitter_archive_master.dog_stage.value_counts().loc[lambda x: x>5][2:]
size = highst_count.size
highst_count.plot.pie(title="DOG STAGE , apperd int tweets for dogs, percentage"
                      ,autopct='%1.1f%%'
                      ,subplots=True
                      ,shadow=True
                      ,radius = 1 ,explode=(0.1 , 0.2 , 0.3 )
                      , figsize=(11, 6)
                      );

# %%
twitter_archive_master.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56+00:00
# 1  892177421306343426  2017-08-01 00:17:27+00:00
# 2  891815181378084864  2017-07-31 00:18:03+00:00
# 3  891689557279858688  2017-07-30 15:58:51+00:00
# 4  891327558926688256  2017-07-29 16:00:24+00:00
#
#                                               source      name  \
# 0  <a href="http://twitter.com/download/iphone" r...   Phineas
# 1  <a href="http://twitter.com/download/iphone" r...     Tilly
# 2  <a href="http://twitter.com/download/iphone" r...    Archie
# 3  <a href="http://twitter.com/download/iphone" r...     Darla
# 4  <a href="http://twitter.com/download/iphone" r...  Franklin
#
#    rating_numerator  rating_denominator   p1  p1_conf p1_dog doggo floofer  \
# 0                13                  10  NaN      NaN    NaN   NaN     NaN
# 1                13                  10  NaN      NaN    NaN   NaN     NaN
# ...

# %%
#twitter_archive_master.groupby('dog_stage',"rating_numerator")#by="rating_numerator").sum()

rating_numerator_count = twitter_archive_master.groupby(['rating_denominator','dog_stage']).size().reset_index().groupby('dog_stage')[[0]].max()
rating_numerator_count
# Out:
#                   0
# dog_stage
# doggo            83
# doggo, floofer    1
# doggo, pupper    12
# doggo, puppo      1
# floofer           9
# pupper          245
# puppo            29

# %%
rating_numerator_count.plot.pie(title="Rating numerator , apperd in tweets for dogs, percentage"
                      ,autopct='%1.1f%%'
                      ,subplots=True
                      ,shadow=True
                      ,radius = 1 ,explode=(0.1 , 0.2 , 0.3 ,0.3 , 0.3 ,0.3, 0.3 )
                      , figsize=(15, 15)
                      );

# %% [markdown]
# ##### MAKE THE PLOT WITHOUT SHADO TO BE MORE CLEAR !!

# %%
rating_numerator_count.plot.pie(title="Rating numerator , apperd in tweets for dogs, percentage"
                      ,autopct='%1.1f%%'
                      ,subplots=True
                      #,shadow=True
                      ,radius = 1 ,explode=(0.1 , 0.2 , 0.3 ,0.3 , 0.3 ,0.3, 0.3 )
                      , figsize=(15, 15)
                      );

# %%
plt.bar(dog_types_count,height=dog_types);
plt.title("dog type ber tweets")
# Out:
# Text(0.5, 1.0, 'dog type ber tweets')

# %%
twitter_archive_master.hist(figsize=(11,11));

# %% [markdown]
# ##### TRYING THE NAMES WITOUT SHADOW TO SEE IF IT BECOME MORE CLEARLY !!!

# %%
highst_count = twitter_archive_master.name.value_counts().loc[lambda x: x>5][2:]
size = highst_count.size
highst_count.plot.pie(title="Most tweeted names for dogs  percentage"
                      ,autopct='%1.1f%%'
                      ,subplots=True
                      #,shadow=True
                      ,radius = 1 #,explode=size
                      , figsize=(11, 6)
                      );

# %%
size
# Out:
# 27
