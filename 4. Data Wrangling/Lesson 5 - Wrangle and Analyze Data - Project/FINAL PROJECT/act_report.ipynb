# %% [markdown]
# ***
#
# # <h1><center>💕💕💕OUR BELOVED  FRIEND 💕💕💕</center></h1>
#
# ***

# %% [markdown]
# ![cover.png](attachment:cover.png)

# %% [markdown]
# ***
# # ALTHO THAT IS  NOT PRECISE
# ## IN project to figure out what people tweet about there dog , name, stage , and what other think about dogs how they rating them as if ther wewere neighbor  dog !!
# ## du to it is data gathered from tweets in a certin era of time but , with this tweets we can come to conclusions :
#
# 1 - WHAT'S YOUR DOG, NEXT DOG NAME !!?
#
# 2 - WHAT people name there dog ? preferred  dog name is 🐶
#
# 3 - Did you think in what stag your next dog , will be , what is most stage that human have !?
#
# 4 - What do you think peoples think about the stage of the other dog , how they rating them ?
# ***

# %% [markdown]
# ## * It's  look like the dog you have named "Charlie " , your next dog will be called "Lucy", if not , then he is "Cooper",  don't tell me its "Oliver" !!.

# %% [markdown]
# ![Screenshot%20%28106%29.png](attachment:Screenshot%20%28106%29.png)

# %% [markdown]
# "Charlie " is the prefered name for most of how tweets about there dog , come next "Lucy", "Cooper", "Oliver" , the lest enclude more names but those are the most comcommon , above a visual for the names appears in the select tweets.

# %% [markdown]
# ## * It's  look like your dog is still "puppo" !!

# %% [markdown]
# ![Screenshot%20%28104%29.png](attachment:Screenshot%20%28104%29.png)

# %% [markdown]
# the "puppo" stage is the stage that almost every dog owners have, with a "58%" next is "dogggo",with "pupper" in a "24%", and lastly the "floofer" stage with "18%" .

# %% [markdown]
# ## * OH  look !, PEOPLE DO LIKE "puppo" !!

# %% [markdown]
# ![Screenshot%20%28105%29.png](attachment:Screenshot%20%28105%29.png)

# %% [markdown]
# ### if you have a dog in "pupper" stage , it's look like when you are walking in the street , anyone who meets you will like your dog, as this stage is the most likely for humans
