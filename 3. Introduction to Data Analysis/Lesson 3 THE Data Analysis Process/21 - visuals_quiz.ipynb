# %% [markdown]
# # Exploring Data with Visuals Quiz
# Use the space below to explore `powerplant_data_edited.csv` to answer the quiz questions below. Remember, you created this dataset at the bottom of the notebook in the "Reading CSV Files" section earlier in the lesson! Check your work with the solutions on that page if you are having trouble getting this dataset.

# %% [markdown]
# # Using the functions you've learned so far,
# ## in the Jupyter notebook below, explore the `powerplant_data_edited.csv` file,
# which you created in the "Reading CSV Files" section earlier in the lesson. You will create visualizations that help answer quiz questions below the notebook about the following information:
#
# relationship between temperature and electrical output
# distribution of humidity
# feature with the most outliers
# Don't forget to include the line that will allow you to view visualizations in the notebook!

# %%
# import and load data
import numpy as np
import pandas as pd

df_powerplant_data =pd.read_csv("powerplant_data_edited.csv")

df_powerplant_data
# Out:
#       Temperature  Exhaust Vacuum  Ambient Pressure  Relative Humidity  \
# 0            8.34           40.77           1010.84              90.01
# 1           23.64           58.49           1011.40              74.20
# 2           29.74           56.90           1007.15              41.91
# 3           19.07           49.69           1007.22              76.79
# 4           11.80           40.66           1017.13              97.20
# ...           ...             ...               ...                ...
# 9563        15.12           48.92           1011.80              72.93
# 9564        33.41           77.95           1010.30              59.72
# 9565        15.99           43.34           1014.20              78.66
# 9566        17.65           59.87           1018.58              94.65
# 9567        23.68           51.30           1011.86              71.24
#
#       net hourly electrical energy output
# 0                                  480.48
# ...

# %%
# plot relationship between temperature and electrical output
df_powerplant_data.plot(x="Temperature",y="net hourly electrical energy output",kind="scatter");

# %%
# plot distribution of humidity
df_powerplant_data["Relative Humidity"].hist();

# %%
# plot box plots for each variable
for i in df_powerplant_data.columns:
    df_powerplant_data[i].plot(kind="bar");

# %%
df['exhaust_vacuum'].plot(kind='box');
